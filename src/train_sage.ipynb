# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics import roc_auc_score, average_precision_score

from models_sage import HeteroGraphSAGE
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE
# Out:
# 'cpu'

# %%
# Reproducibility control
import torch, random, numpy as np

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
SEEDS = [42, 43, 44, 45, 46]

# %%
# Notebook-safe paths
ROOT = Path.cwd().parent

DATA_DIR = ROOT / "data" / "data_cleaned"
GRAPH_PATH = ROOT / "outputs" / "data.pt"
OUT_DIR = ROOT / "outputs"
OUT_DIR.mkdir(exist_ok=True)

print("ROOT:", ROOT)
print("DATA_DIR:", DATA_DIR)
print("GRAPH_PATH:", GRAPH_PATH)
# Out:
# ROOT: C:\Users\ayish\OneDrive\Documents\circRNA-disease-gnn
# DATA_DIR: C:\Users\ayish\OneDrive\Documents\circRNA-disease-gnn\data\data_cleaned
# GRAPH_PATH: C:\Users\ayish\OneDrive\Documents\circRNA-disease-gnn\outputs\data.pt

# %% [markdown]
# ### Load node preserving labelled splits

# %%
def load_split(name, le_circ, le_dis):
    df = pd.read_csv(DATA_DIR / name)

    # Encode node names → integer IDs
    circ_ids = le_circ.transform(df["circRNA"].astype(str))
    dis_ids  = le_dis.transform(df["disease"].astype(str))

    # Build edge index: [2, num_edges]
    edges = torch.from_numpy(np.vstack([circ_ids, dis_ids])).long()

    # Labels (already numeric)
    labels = torch.tensor(df["label"].values, dtype=torch.float)

    return edges, labels

# %%
encoders = torch.load(
    OUT_DIR / "label_encoders.pt",
    weights_only=False
)

le_circ = encoders["circRNA"]
le_dis  = encoders["disease"]


train_edges, train_labels = load_split("circRNA_disease_train.csv", le_circ, le_dis)
val_edges, val_labels     = load_split("circRNA_disease_val.csv", le_circ, le_dis)
test_edges, test_labels   = load_split("circRNA_disease_test.csv", le_circ, le_dis)

train_edges.shape, train_labels.shape
# Out:
# (torch.Size([2, 929]), torch.Size([929]))

# %% [markdown]
# ### Move Splits to Device

# %%
train_edges, train_labels = train_edges.to(DEVICE), train_labels.to(DEVICE)
val_edges, val_labels     = val_edges.to(DEVICE), val_labels.to(DEVICE)
test_edges, test_labels   = test_edges.to(DEVICE), test_labels.to(DEVICE)

# %% [markdown]
# ### Load HeteroGraph

# %%
print("Loading heterogeneous graph...")
data = torch.load(
    GRAPH_PATH,
    map_location=DEVICE,
    weights_only=False
)

data
# Out:
# Loading heterogeneous graph...
# HeteroData(
#   circRNA={ x=[828, 6] },
#   miRNA={ x=[521, 6] },
#   disease={ x=[122, 6] },
#   (circRNA, interacts, miRNA)={ edge_index=[2, 896] },
#   (miRNA, interacts, disease)={ edge_index=[2, 828] },
#   (circRNA, associated, disease)={ edge_index=[2, 985] },
#   (circRNA, gip_sim, circRNA)={
#     edge_index=[2, 685584],
#     edge_weight=[685584],
#   },
#   (miRNA, gip_sim, miRNA)={
#     edge_index=[2, 271441],
#     edge_weight=[271441],
#   },
#   (miRNA, rev_interacts, circRNA)={ edge_index=[2, 896] },
#   (disease, rev_interacts, miRNA)={ edge_index=[2, 828] },
#   (disease, rev_associated, circRNA)={ edge_index=[2, 985] }
# )

# %% [markdown]
# ### Initialize GraphSAGE model

# %% [raw]
# model = HeteroGraphSAGE(
#     in_channels=data["circRNA"].x.size(1),
#     hidden_channels=64,
#     out_channels=64,
#     dropout=0.2
# ).to(DEVICE)
#
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# loss_fn = nn.BCEWithLogitsLoss()
#
# model

# %% [raw]
# best_val_aupr = 0.0
#
# print("\nStarting GraphSAGE training...\n")
#
# for epoch in range(1, 51):
#     # -------- Training --------
#     model.train()
#     optimizer.zero_grad()
#
#     emb = model(data.x_dict, data.edge_index_dict)
#     circ_emb, dis_emb = emb["circRNA"], emb["disease"]
#
#     logits = (circ_emb[train_edges[0]] * dis_emb[train_edges[1]]).sum(dim=1)
#     loss = loss_fn(logits, train_labels)
#
#     loss.backward()
#     optimizer.step()
#
#     # -------- Validation --------
#     model.eval()
#     with torch.no_grad():
#         emb = model(data.x_dict, data.edge_index_dict)
#         circ_emb, dis_emb = emb["circRNA"], emb["disease"]
#
#         val_logits = (circ_emb[val_edges[0]] * dis_emb[val_edges[1]]).sum(dim=1)
#         val_scores = torch.sigmoid(val_logits).cpu().numpy()
#         val_true   = val_labels.cpu().numpy()
#
#         auc = roc_auc_score(val_true, val_scores)
#         aupr = average_precision_score(val_true, val_scores)
#
#     print(
#         f"Epoch {epoch:03d} | "
#         f"Loss {loss.item():.4f} | "
#         f"Val AUC {auc:.4f} | "
#         f"Val AUPR {aupr:.4f}"
#     )
#
#     if aupr > best_val_aupr:
#         best_val_aupr = aupr
#         torch.save(model.state_dict(), OUT_DIR / "sage_best_model.pth")
#         print("   → Saved best model")

# %% [raw]
# print("\nEvaluating on test set...")
#
# model.load_state_dict(torch.load(OUT_DIR / "sage_best_model.pth", map_location=DEVICE))
# model.eval()
#
# with torch.no_grad():
#     emb = model(data.x_dict, data.edge_index_dict)
#     circ_emb, dis_emb = emb["circRNA"], emb["disease"]
#
#     test_logits = (circ_emb[test_edges[0]] * dis_emb[test_edges[1]]).sum(dim=1)
#     test_scores = torch.sigmoid(test_logits).cpu().numpy()
#     test_true   = test_labels.cpu().numpy()
#
#     test_auc = roc_auc_score(test_true, test_scores)
#     test_aupr = average_precision_score(test_true, test_scores)
#
# print("\nFINAL TEST RESULTS")
# print(f"AUC  = {test_auc:.4f}")
# print(f"AUPR = {test_aupr:.4f}")

# %%
results = []

for seed in SEEDS:
    print(f"\n==============================")
    print(f"Running experiment with SEED = {seed}")
    print(f"==============================")

    set_seed(seed)

    # ---- model must be re-created AFTER seed ----
    model = HeteroGraphSAGE(
        in_channels=data["circRNA"].x.size(1),
        hidden_channels=64,
        out_channels=64,
        dropout=0.2
    ).to(DEVICE)

    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.BCEWithLogitsLoss()

    best_val_aupr = 0.0
    best_val_loss = None


    # -------- Training loop --------
    for epoch in range(1, 51):
        model.train()
        optimizer.zero_grad()

        emb = model(data.x_dict, data.edge_index_dict)
        circ_emb, dis_emb = emb["circRNA"], emb["disease"]

        logits = (circ_emb[train_edges[0]] * dis_emb[train_edges[1]]).sum(dim=1)
        loss = loss_fn(logits, train_labels)

        loss.backward()
        optimizer.step()

        # -------- Validation --------
        model.eval()
        with torch.no_grad():
            emb = model(data.x_dict, data.edge_index_dict)
            circ_emb, dis_emb = emb["circRNA"], emb["disease"]

            val_logits = (circ_emb[val_edges[0]] * dis_emb[val_edges[1]]).sum(dim=1)
            val_scores = torch.sigmoid(val_logits).cpu().numpy()
            val_true   = val_labels.cpu().numpy()

            auc = roc_auc_score(val_true, val_scores)
            aupr = average_precision_score(val_true, val_scores)
        print(
        f"Epoch {epoch:03d} | "
        f"Loss {loss.item():.4f} | "
        f"Val AUC {auc:.4f} | "
        f"Val AUPR {aupr:.4f}"
        )

        if aupr > best_val_aupr:
            best_val_aupr = aupr
            best_val_loss = loss.item()
            torch.save(
                model.state_dict(),
                OUT_DIR / f"sage_best_model_seed{seed}.pth"
            )
            print("   → Saved best model")

    # -------- Test evaluation --------
    model.load_state_dict(
        torch.load(OUT_DIR / f"sage_best_model_seed{seed}.pth", map_location=DEVICE)
    )
    model.eval()

    with torch.no_grad():
        emb = model(data.x_dict, data.edge_index_dict)
        circ_emb, dis_emb = emb["circRNA"], emb["disease"]

        test_logits = (circ_emb[test_edges[0]] * dis_emb[test_edges[1]]).sum(dim=1)
        test_scores = torch.sigmoid(test_logits).cpu().numpy()
        test_true   = test_labels.cpu().numpy()

        test_auc  = roc_auc_score(test_true, test_scores)
        test_aupr = average_precision_score(test_true, test_scores)

    print(f"SEED {seed} | Test AUC {test_auc:.4f} | Test AUPR {test_aupr:.4f}")

    results.append((seed, best_val_loss, test_auc, test_aupr))
# Out:
# ==============================
# Running experiment with SEED = 42
# ==============================
# 3Layer
# 3Layer
# Epoch 001 | Loss 0.6651 | Val AUC 0.6636 | Val AUPR 0.1530
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 002 | Loss 0.5648 | Val AUC 0.7998 | Val AUPR 0.2544
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 003 | Loss 0.5086 | Val AUC 0.8381 | Val AUPR 0.3092
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 004 | Loss 0.4651 | Val AUC 0.8661 | Val AUPR 0.3736
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 005 | Loss 0.4416 | Val AUC 0.8860 | Val AUPR 0.4725
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 006 | Loss 0.4283 | Val AUC 0.9002 | Val AUPR 0.5380
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 007 | Loss 0.4220 | Val AUC 0.9064 | Val AUPR 0.5623
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 008 | Loss 0.4169 | Val AUC 0.9075 | Val AUPR 0.5406
# 3Layer
# 3Layer
# Epoch 009 | Loss 0.4144 | Val AUC 0.9073 | Val AUPR 0.5254
# 3Layer
# 3Layer
# Epoch 010 | Loss 0.4115 | Val AUC 0.9072 | Val AUPR 0.5192
# 3Layer
# 3Layer
# Epoch 011 | Loss 0.4088 | Val AUC 0.9066 | Val AUPR 0.5157
# 3Layer
# 3Layer
# Epoch 012 | Loss 0.4059 | Val AUC 0.9076 | Val AUPR 0.5202
# 3Layer
# 3Layer
# Epoch 013 | Loss 0.4027 | Val AUC 0.9082 | Val AUPR 0.5190
# 3Layer
# 3Layer
# Epoch 014 | Loss 0.4017 | Val AUC 0.9094 | Val AUPR 0.5158
# 3Layer
# 3Layer
# Epoch 015 | Loss 0.3992 | Val AUC 0.9097 | Val AUPR 0.5152
# 3Layer
# 3Layer
# Epoch 016 | Loss 0.3976 | Val AUC 0.9101 | Val AUPR 0.5246
# 3Layer
# 3Layer
# Epoch 017 | Loss 0.3964 | Val AUC 0.9104 | Val AUPR 0.5299
# 3Layer
# 3Layer
# Epoch 018 | Loss 0.3942 | Val AUC 0.9104 | Val AUPR 0.5435
# 3Layer
# 3Layer
# Epoch 019 | Loss 0.3941 | Val AUC 0.9106 | Val AUPR 0.5495
# 3Layer
# 3Layer
# Epoch 020 | Loss 0.3942 | Val AUC 0.9102 | Val AUPR 0.5505
# 3Layer
# 3Layer
# Epoch 021 | Loss 0.3926 | Val AUC 0.9099 | Val AUPR 0.5441
# 3Layer
# 3Layer
# Epoch 022 | Loss 0.3925 | Val AUC 0.9089 | Val AUPR 0.5434
# 3Layer
# 3Layer
# Epoch 023 | Loss 0.3914 | Val AUC 0.9083 | Val AUPR 0.5396
# 3Layer
# 3Layer
# Epoch 024 | Loss 0.3922 | Val AUC 0.9084 | Val AUPR 0.5519
# 3Layer
# 3Layer
# Epoch 025 | Loss 0.3922 | Val AUC 0.9087 | Val AUPR 0.5545
# 3Layer
# 3Layer
# Epoch 026 | Loss 0.3908 | Val AUC 0.9091 | Val AUPR 0.5547
# 3Layer
# 3Layer
# Epoch 027 | Loss 0.3906 | Val AUC 0.9097 | Val AUPR 0.5668
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 028 | Loss 0.3897 | Val AUC 0.9104 | Val AUPR 0.5681
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 029 | Loss 0.3894 | Val AUC 0.9114 | Val AUPR 0.5738
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 030 | Loss 0.3896 | Val AUC 0.9126 | Val AUPR 0.5767
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 031 | Loss 0.3892 | Val AUC 0.9133 | Val AUPR 0.5803
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 032 | Loss 0.3889 | Val AUC 0.9142 | Val AUPR 0.5813
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 033 | Loss 0.3890 | Val AUC 0.9157 | Val AUPR 0.5870
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 034 | Loss 0.3889 | Val AUC 0.9179 | Val AUPR 0.5924
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 035 | Loss 0.3886 | Val AUC 0.9199 | Val AUPR 0.6014
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 036 | Loss 0.3878 | Val AUC 0.9215 | Val AUPR 0.6064
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 037 | Loss 0.3878 | Val AUC 0.9233 | Val AUPR 0.6129
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 038 | Loss 0.3877 | Val AUC 0.9258 | Val AUPR 0.6220
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 039 | Loss 0.3874 | Val AUC 0.9269 | Val AUPR 0.6282
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 040 | Loss 0.3868 | Val AUC 0.9275 | Val AUPR 0.6354
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 041 | Loss 0.3867 | Val AUC 0.9273 | Val AUPR 0.6347
# 3Layer
# 3Layer
# Epoch 042 | Loss 0.3864 | Val AUC 0.9277 | Val AUPR 0.6394
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 043 | Loss 0.3863 | Val AUC 0.9282 | Val AUPR 0.6434
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 044 | Loss 0.3855 | Val AUC 0.9284 | Val AUPR 0.6454
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 045 | Loss 0.3853 | Val AUC 0.9290 | Val AUPR 0.6492
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 046 | Loss 0.3844 | Val AUC 0.9288 | Val AUPR 0.6443
# 3Layer
# 3Layer
# Epoch 047 | Loss 0.3842 | Val AUC 0.9295 | Val AUPR 0.6486
# 3Layer
# 3Layer
# Epoch 048 | Loss 0.3842 | Val AUC 0.9296 | Val AUPR 0.6472
# 3Layer
# 3Layer
# Epoch 049 | Loss 0.3839 | Val AUC 0.9302 | Val AUPR 0.6441
# 3Layer
# 3Layer
# Epoch 050 | Loss 0.3834 | Val AUC 0.9305 | Val AUPR 0.6447
# 3Layer
# SEED 42 | Test AUC 0.9219 | Test AUPR 0.5700
#
# ==============================
# Running experiment with SEED = 43
# ==============================
# 3Layer
# 3Layer
# Epoch 001 | Loss 0.7201 | Val AUC 0.7575 | Val AUPR 0.2080
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 002 | Loss 0.6123 | Val AUC 0.8752 | Val AUPR 0.4372
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 003 | Loss 0.5412 | Val AUC 0.9058 | Val AUPR 0.5818
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 004 | Loss 0.4909 | Val AUC 0.9106 | Val AUPR 0.6475
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 005 | Loss 0.4662 | Val AUC 0.9123 | Val AUPR 0.6591
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 006 | Loss 0.4437 | Val AUC 0.9116 | Val AUPR 0.6307
# 3Layer
# 3Layer
# Epoch 007 | Loss 0.4360 | Val AUC 0.9100 | Val AUPR 0.5735
# 3Layer
# 3Layer
# Epoch 008 | Loss 0.4265 | Val AUC 0.9043 | Val AUPR 0.5688
# 3Layer
# 3Layer
# Epoch 009 | Loss 0.4233 | Val AUC 0.8977 | Val AUPR 0.5612
# 3Layer
# 3Layer
# Epoch 010 | Loss 0.4191 | Val AUC 0.8912 | Val AUPR 0.5480
# 3Layer
# 3Layer
# Epoch 011 | Loss 0.4155 | Val AUC 0.8899 | Val AUPR 0.5408
# 3Layer
# 3Layer
# Epoch 012 | Loss 0.4137 | Val AUC 0.8902 | Val AUPR 0.5292
# 3Layer
# 3Layer
# Epoch 013 | Loss 0.4081 | Val AUC 0.8939 | Val AUPR 0.5278
# 3Layer
# 3Layer
# Epoch 014 | Loss 0.4063 | Val AUC 0.8982 | Val AUPR 0.5422
# 3Layer
# 3Layer
# Epoch 015 | Loss 0.4052 | Val AUC 0.9039 | Val AUPR 0.5747
# 3Layer
# 3Layer
# Epoch 016 | Loss 0.4009 | Val AUC 0.9107 | Val AUPR 0.6262
# 3Layer
# 3Layer
# Epoch 017 | Loss 0.3999 | Val AUC 0.9173 | Val AUPR 0.6652
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 018 | Loss 0.3991 | Val AUC 0.9230 | Val AUPR 0.7024
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 019 | Loss 0.3968 | Val AUC 0.9271 | Val AUPR 0.7282
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 020 | Loss 0.3966 | Val AUC 0.9297 | Val AUPR 0.7394
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 021 | Loss 0.3953 | Val AUC 0.9306 | Val AUPR 0.7337
# 3Layer
# 3Layer
# Epoch 022 | Loss 0.3936 | Val AUC 0.9302 | Val AUPR 0.7234
# 3Layer
# 3Layer
# Epoch 023 | Loss 0.3931 | Val AUC 0.9289 | Val AUPR 0.6954
# 3Layer
# 3Layer
# Epoch 024 | Loss 0.3924 | Val AUC 0.9271 | Val AUPR 0.6551
# 3Layer
# 3Layer
# Epoch 025 | Loss 0.3918 | Val AUC 0.9257 | Val AUPR 0.6268
# 3Layer
# 3Layer
# Epoch 026 | Loss 0.3922 | Val AUC 0.9251 | Val AUPR 0.6128
# 3Layer
# 3Layer
# Epoch 027 | Loss 0.3921 | Val AUC 0.9244 | Val AUPR 0.6014
# 3Layer
# 3Layer
# Epoch 028 | Loss 0.3933 | Val AUC 0.9236 | Val AUPR 0.5869
# 3Layer
# 3Layer
# Epoch 029 | Loss 0.3912 | Val AUC 0.9225 | Val AUPR 0.5724
# 3Layer
# 3Layer
# Epoch 030 | Loss 0.3904 | Val AUC 0.9218 | Val AUPR 0.5680
# 3Layer
# 3Layer
# Epoch 031 | Loss 0.3909 | Val AUC 0.9210 | Val AUPR 0.5609
# 3Layer
# 3Layer
# Epoch 032 | Loss 0.3902 | Val AUC 0.9212 | Val AUPR 0.5602
# 3Layer
# 3Layer
# Epoch 033 | Loss 0.3893 | Val AUC 0.9215 | Val AUPR 0.5648
# 3Layer
# 3Layer
# Epoch 034 | Loss 0.3897 | Val AUC 0.9217 | Val AUPR 0.5693
# 3Layer
# 3Layer
# Epoch 035 | Loss 0.3900 | Val AUC 0.9220 | Val AUPR 0.5757
# 3Layer
# 3Layer
# Epoch 036 | Loss 0.3889 | Val AUC 0.9222 | Val AUPR 0.5775
# 3Layer
# 3Layer
# Epoch 037 | Loss 0.3890 | Val AUC 0.9232 | Val AUPR 0.5939
# 3Layer
# 3Layer
# Epoch 038 | Loss 0.3888 | Val AUC 0.9243 | Val AUPR 0.6045
# 3Layer
# 3Layer
# Epoch 039 | Loss 0.3880 | Val AUC 0.9247 | Val AUPR 0.6091
# 3Layer
# 3Layer
# Epoch 040 | Loss 0.3878 | Val AUC 0.9253 | Val AUPR 0.6201
# 3Layer
# 3Layer
# Epoch 041 | Loss 0.3871 | Val AUC 0.9261 | Val AUPR 0.6210
# 3Layer
# 3Layer
# Epoch 042 | Loss 0.3872 | Val AUC 0.9271 | Val AUPR 0.6316
# 3Layer
# 3Layer
# Epoch 043 | Loss 0.3869 | Val AUC 0.9279 | Val AUPR 0.6422
# 3Layer
# 3Layer
# Epoch 044 | Loss 0.3863 | Val AUC 0.9290 | Val AUPR 0.6537
# 3Layer
# 3Layer
# Epoch 045 | Loss 0.3860 | Val AUC 0.9299 | Val AUPR 0.6649
# 3Layer
# 3Layer
# Epoch 046 | Loss 0.3855 | Val AUC 0.9311 | Val AUPR 0.6749
# 3Layer
# 3Layer
# Epoch 047 | Loss 0.3852 | Val AUC 0.9318 | Val AUPR 0.6816
# 3Layer
# 3Layer
# Epoch 048 | Loss 0.3853 | Val AUC 0.9320 | Val AUPR 0.6857
# 3Layer
# 3Layer
# Epoch 049 | Loss 0.3853 | Val AUC 0.9325 | Val AUPR 0.6897
# 3Layer
# 3Layer
# Epoch 050 | Loss 0.3837 | Val AUC 0.9326 | Val AUPR 0.6920
# 3Layer
# SEED 43 | Test AUC 0.9245 | Test AUPR 0.6163
#
# ==============================
# Running experiment with SEED = 44
# ==============================
# 3Layer
# 3Layer
# Epoch 001 | Loss 0.7226 | Val AUC 0.4573 | Val AUPR 0.1004
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 002 | Loss 0.6128 | Val AUC 0.7552 | Val AUPR 0.2026
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 003 | Loss 0.5311 | Val AUC 0.8342 | Val AUPR 0.3063
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 004 | Loss 0.4812 | Val AUC 0.8733 | Val AUPR 0.4108
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 005 | Loss 0.4573 | Val AUC 0.8885 | Val AUPR 0.4487
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 006 | Loss 0.4436 | Val AUC 0.8955 | Val AUPR 0.4741
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 007 | Loss 0.4326 | Val AUC 0.8999 | Val AUPR 0.4905
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 008 | Loss 0.4264 | Val AUC 0.9037 | Val AUPR 0.5140
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 009 | Loss 0.4188 | Val AUC 0.9081 | Val AUPR 0.5467
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 010 | Loss 0.4167 | Val AUC 0.9116 | Val AUPR 0.5727
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 011 | Loss 0.4127 | Val AUC 0.9135 | Val AUPR 0.5898
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 012 | Loss 0.4106 | Val AUC 0.9152 | Val AUPR 0.6229
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 013 | Loss 0.4075 | Val AUC 0.9160 | Val AUPR 0.6620
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 014 | Loss 0.4048 | Val AUC 0.9165 | Val AUPR 0.6909
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 015 | Loss 0.4032 | Val AUC 0.9165 | Val AUPR 0.6923
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 016 | Loss 0.4018 | Val AUC 0.9160 | Val AUPR 0.6939
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 017 | Loss 0.3996 | Val AUC 0.9154 | Val AUPR 0.6881
# 3Layer
# 3Layer
# Epoch 018 | Loss 0.3970 | Val AUC 0.9151 | Val AUPR 0.6797
# 3Layer
# 3Layer
# Epoch 019 | Loss 0.3958 | Val AUC 0.9152 | Val AUPR 0.6751
# 3Layer
# 3Layer
# Epoch 020 | Loss 0.3964 | Val AUC 0.9144 | Val AUPR 0.6501
# 3Layer
# 3Layer
# Epoch 021 | Loss 0.3938 | Val AUC 0.9144 | Val AUPR 0.6447
# 3Layer
# 3Layer
# Epoch 022 | Loss 0.3940 | Val AUC 0.9140 | Val AUPR 0.6248
# 3Layer
# 3Layer
# Epoch 023 | Loss 0.3935 | Val AUC 0.9119 | Val AUPR 0.6021
# 3Layer
# 3Layer
# Epoch 024 | Loss 0.3937 | Val AUC 0.9113 | Val AUPR 0.5858
# 3Layer
# 3Layer
# Epoch 025 | Loss 0.3923 | Val AUC 0.9090 | Val AUPR 0.5618
# 3Layer
# 3Layer
# Epoch 026 | Loss 0.3917 | Val AUC 0.9072 | Val AUPR 0.5366
# 3Layer
# 3Layer
# Epoch 027 | Loss 0.3912 | Val AUC 0.9065 | Val AUPR 0.5286
# 3Layer
# 3Layer
# Epoch 028 | Loss 0.3912 | Val AUC 0.9061 | Val AUPR 0.5228
# 3Layer
# 3Layer
# Epoch 029 | Loss 0.3904 | Val AUC 0.9064 | Val AUPR 0.5257
# 3Layer
# 3Layer
# Epoch 030 | Loss 0.3909 | Val AUC 0.9071 | Val AUPR 0.5238
# 3Layer
# 3Layer
# Epoch 031 | Loss 0.3902 | Val AUC 0.9085 | Val AUPR 0.5319
# 3Layer
# 3Layer
# Epoch 032 | Loss 0.3903 | Val AUC 0.9093 | Val AUPR 0.5344
# 3Layer
# 3Layer
# Epoch 033 | Loss 0.3902 | Val AUC 0.9109 | Val AUPR 0.5428
# 3Layer
# 3Layer
# Epoch 034 | Loss 0.3898 | Val AUC 0.9121 | Val AUPR 0.5551
# 3Layer
# 3Layer
# Epoch 035 | Loss 0.3892 | Val AUC 0.9134 | Val AUPR 0.5716
# 3Layer
# 3Layer
# Epoch 036 | Loss 0.3894 | Val AUC 0.9146 | Val AUPR 0.5733
# 3Layer
# 3Layer
# Epoch 037 | Loss 0.3893 | Val AUC 0.9155 | Val AUPR 0.5858
# 3Layer
# 3Layer
# Epoch 038 | Loss 0.3884 | Val AUC 0.9164 | Val AUPR 0.5950
# 3Layer
# 3Layer
# Epoch 039 | Loss 0.3888 | Val AUC 0.9166 | Val AUPR 0.6030
# 3Layer
# 3Layer
# Epoch 040 | Loss 0.3884 | Val AUC 0.9164 | Val AUPR 0.6032
# 3Layer
# 3Layer
# Epoch 041 | Loss 0.3880 | Val AUC 0.9168 | Val AUPR 0.6046
# 3Layer
# 3Layer
# Epoch 042 | Loss 0.3881 | Val AUC 0.9172 | Val AUPR 0.6052
# 3Layer
# 3Layer
# Epoch 043 | Loss 0.3879 | Val AUC 0.9174 | Val AUPR 0.6058
# 3Layer
# 3Layer
# Epoch 044 | Loss 0.3880 | Val AUC 0.9174 | Val AUPR 0.6048
# 3Layer
# 3Layer
# Epoch 045 | Loss 0.3876 | Val AUC 0.9173 | Val AUPR 0.6018
# 3Layer
# 3Layer
# Epoch 046 | Loss 0.3874 | Val AUC 0.9170 | Val AUPR 0.5957
# 3Layer
# 3Layer
# Epoch 047 | Loss 0.3874 | Val AUC 0.9173 | Val AUPR 0.5950
# 3Layer
# 3Layer
# Epoch 048 | Loss 0.3867 | Val AUC 0.9181 | Val AUPR 0.6094
# 3Layer
# 3Layer
# Epoch 049 | Loss 0.3866 | Val AUC 0.9191 | Val AUPR 0.6190
# 3Layer
# 3Layer
# Epoch 050 | Loss 0.3869 | Val AUC 0.9203 | Val AUPR 0.6234
# 3Layer
# SEED 44 | Test AUC 0.9292 | Test AUPR 0.6411
#
# ==============================
# Running experiment with SEED = 45
# ==============================
# 3Layer
# 3Layer
# Epoch 001 | Loss 0.7062 | Val AUC 0.6722 | Val AUPR 0.1567
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 002 | Loss 0.6116 | Val AUC 0.7437 | Val AUPR 0.1955
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 003 | Loss 0.5318 | Val AUC 0.8140 | Val AUPR 0.2755
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 004 | Loss 0.4840 | Val AUC 0.8500 | Val AUPR 0.3443
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 005 | Loss 0.4539 | Val AUC 0.8726 | Val AUPR 0.4090
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 006 | Loss 0.4377 | Val AUC 0.8841 | Val AUPR 0.4356
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 007 | Loss 0.4322 | Val AUC 0.8926 | Val AUPR 0.4583
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 008 | Loss 0.4263 | Val AUC 0.9036 | Val AUPR 0.4909
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 009 | Loss 0.4224 | Val AUC 0.9106 | Val AUPR 0.5153
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 010 | Loss 0.4188 | Val AUC 0.9156 | Val AUPR 0.5389
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 011 | Loss 0.4156 | Val AUC 0.9207 | Val AUPR 0.5626
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 012 | Loss 0.4113 | Val AUC 0.9233 | Val AUPR 0.5813
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 013 | Loss 0.4065 | Val AUC 0.9241 | Val AUPR 0.5914
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 014 | Loss 0.4051 | Val AUC 0.9241 | Val AUPR 0.5917
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 015 | Loss 0.4023 | Val AUC 0.9231 | Val AUPR 0.5894
# 3Layer
# 3Layer
# Epoch 016 | Loss 0.4001 | Val AUC 0.9218 | Val AUPR 0.5864
# 3Layer
# 3Layer
# Epoch 017 | Loss 0.3988 | Val AUC 0.9202 | Val AUPR 0.5937
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 018 | Loss 0.3980 | Val AUC 0.9174 | Val AUPR 0.5777
# 3Layer
# 3Layer
# Epoch 019 | Loss 0.3957 | Val AUC 0.9144 | Val AUPR 0.5727
# 3Layer
# 3Layer
# Epoch 020 | Loss 0.3953 | Val AUC 0.9106 | Val AUPR 0.5602
# 3Layer
# 3Layer
# Epoch 021 | Loss 0.3947 | Val AUC 0.9066 | Val AUPR 0.5440
# 3Layer
# 3Layer
# Epoch 022 | Loss 0.3935 | Val AUC 0.9027 | Val AUPR 0.5241
# 3Layer
# 3Layer
# Epoch 023 | Loss 0.3937 | Val AUC 0.8983 | Val AUPR 0.4999
# 3Layer
# 3Layer
# Epoch 024 | Loss 0.3921 | Val AUC 0.8951 | Val AUPR 0.4971
# 3Layer
# 3Layer
# Epoch 025 | Loss 0.3917 | Val AUC 0.8924 | Val AUPR 0.4878
# 3Layer
# 3Layer
# Epoch 026 | Loss 0.3919 | Val AUC 0.8901 | Val AUPR 0.4783
# 3Layer
# 3Layer
# Epoch 027 | Loss 0.3915 | Val AUC 0.8881 | Val AUPR 0.4617
# 3Layer
# 3Layer
# Epoch 028 | Loss 0.3915 | Val AUC 0.8874 | Val AUPR 0.4651
# 3Layer
# 3Layer
# Epoch 029 | Loss 0.3906 | Val AUC 0.8876 | Val AUPR 0.4641
# 3Layer
# 3Layer
# Epoch 030 | Loss 0.3900 | Val AUC 0.8886 | Val AUPR 0.4697
# 3Layer
# 3Layer
# Epoch 031 | Loss 0.3898 | Val AUC 0.8897 | Val AUPR 0.4699
# 3Layer
# 3Layer
# Epoch 032 | Loss 0.3894 | Val AUC 0.8925 | Val AUPR 0.4899
# 3Layer
# 3Layer
# Epoch 033 | Loss 0.3894 | Val AUC 0.8952 | Val AUPR 0.5056
# 3Layer
# 3Layer
# Epoch 034 | Loss 0.3891 | Val AUC 0.8983 | Val AUPR 0.5193
# 3Layer
# 3Layer
# Epoch 035 | Loss 0.3887 | Val AUC 0.9013 | Val AUPR 0.5385
# 3Layer
# 3Layer
# Epoch 036 | Loss 0.3884 | Val AUC 0.9036 | Val AUPR 0.5459
# 3Layer
# 3Layer
# Epoch 037 | Loss 0.3884 | Val AUC 0.9055 | Val AUPR 0.5508
# 3Layer
# 3Layer
# Epoch 038 | Loss 0.3875 | Val AUC 0.9087 | Val AUPR 0.5630
# 3Layer
# 3Layer
# Epoch 039 | Loss 0.3876 | Val AUC 0.9107 | Val AUPR 0.5711
# 3Layer
# 3Layer
# Epoch 040 | Loss 0.3870 | Val AUC 0.9126 | Val AUPR 0.5700
# 3Layer
# 3Layer
# Epoch 041 | Loss 0.3871 | Val AUC 0.9144 | Val AUPR 0.5771
# 3Layer
# 3Layer
# Epoch 042 | Loss 0.3869 | Val AUC 0.9157 | Val AUPR 0.5833
# 3Layer
# 3Layer
# Epoch 043 | Loss 0.3867 | Val AUC 0.9168 | Val AUPR 0.5843
# 3Layer
# 3Layer
# Epoch 044 | Loss 0.3869 | Val AUC 0.9177 | Val AUPR 0.5806
# 3Layer
# 3Layer
# Epoch 045 | Loss 0.3861 | Val AUC 0.9187 | Val AUPR 0.5810
# 3Layer
# 3Layer
# Epoch 046 | Loss 0.3857 | Val AUC 0.9198 | Val AUPR 0.5867
# 3Layer
# 3Layer
# Epoch 047 | Loss 0.3851 | Val AUC 0.9207 | Val AUPR 0.5964
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 048 | Loss 0.3855 | Val AUC 0.9220 | Val AUPR 0.6158
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 049 | Loss 0.3852 | Val AUC 0.9225 | Val AUPR 0.6231
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 050 | Loss 0.3851 | Val AUC 0.9222 | Val AUPR 0.6350
#    → Saved best model
# 3Layer
# SEED 45 | Test AUC 0.9332 | Test AUPR 0.5961
#
# ==============================
# Running experiment with SEED = 46
# ==============================
# 3Layer
# 3Layer
# Epoch 001 | Loss 0.6737 | Val AUC 0.4355 | Val AUPR 0.0972
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 002 | Loss 0.5757 | Val AUC 0.5762 | Val AUPR 0.1255
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 003 | Loss 0.5197 | Val AUC 0.7595 | Val AUPR 0.2055
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 004 | Loss 0.4747 | Val AUC 0.8400 | Val AUPR 0.2823
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 005 | Loss 0.4477 | Val AUC 0.8869 | Val AUPR 0.3937
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 006 | Loss 0.4395 | Val AUC 0.9017 | Val AUPR 0.4555
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 007 | Loss 0.4289 | Val AUC 0.9020 | Val AUPR 0.4771
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 008 | Loss 0.4261 | Val AUC 0.9001 | Val AUPR 0.4851
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 009 | Loss 0.4201 | Val AUC 0.8966 | Val AUPR 0.4650
# 3Layer
# 3Layer
# Epoch 010 | Loss 0.4159 | Val AUC 0.8982 | Val AUPR 0.4648
# 3Layer
# 3Layer
# Epoch 011 | Loss 0.4144 | Val AUC 0.8993 | Val AUPR 0.4646
# 3Layer
# 3Layer
# Epoch 012 | Loss 0.4092 | Val AUC 0.9009 | Val AUPR 0.4685
# 3Layer
# 3Layer
# Epoch 013 | Loss 0.4072 | Val AUC 0.9043 | Val AUPR 0.4814
# 3Layer
# 3Layer
# Epoch 014 | Loss 0.4053 | Val AUC 0.9072 | Val AUPR 0.4952
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 015 | Loss 0.4030 | Val AUC 0.9098 | Val AUPR 0.5085
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 016 | Loss 0.4012 | Val AUC 0.9126 | Val AUPR 0.5313
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 017 | Loss 0.3990 | Val AUC 0.9153 | Val AUPR 0.5485
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 018 | Loss 0.3977 | Val AUC 0.9183 | Val AUPR 0.5630
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 019 | Loss 0.3973 | Val AUC 0.9199 | Val AUPR 0.5811
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 020 | Loss 0.3957 | Val AUC 0.9206 | Val AUPR 0.5897
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 021 | Loss 0.3948 | Val AUC 0.9212 | Val AUPR 0.6059
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 022 | Loss 0.3943 | Val AUC 0.9216 | Val AUPR 0.6129
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 023 | Loss 0.3939 | Val AUC 0.9210 | Val AUPR 0.6121
# 3Layer
# 3Layer
# Epoch 024 | Loss 0.3929 | Val AUC 0.9208 | Val AUPR 0.6124
# 3Layer
# 3Layer
# Epoch 025 | Loss 0.3918 | Val AUC 0.9214 | Val AUPR 0.6083
# 3Layer
# 3Layer
# Epoch 026 | Loss 0.3917 | Val AUC 0.9217 | Val AUPR 0.6141
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 027 | Loss 0.3915 | Val AUC 0.9221 | Val AUPR 0.6212
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 028 | Loss 0.3909 | Val AUC 0.9224 | Val AUPR 0.6208
# 3Layer
# 3Layer
# Epoch 029 | Loss 0.3905 | Val AUC 0.9223 | Val AUPR 0.6160
# 3Layer
# 3Layer
# Epoch 030 | Loss 0.3901 | Val AUC 0.9229 | Val AUPR 0.6193
# 3Layer
# 3Layer
# Epoch 031 | Loss 0.3886 | Val AUC 0.9234 | Val AUPR 0.6225
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 032 | Loss 0.3888 | Val AUC 0.9240 | Val AUPR 0.6263
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 033 | Loss 0.3887 | Val AUC 0.9250 | Val AUPR 0.6395
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 034 | Loss 0.3873 | Val AUC 0.9251 | Val AUPR 0.6375
# 3Layer
# 3Layer
# Epoch 035 | Loss 0.3882 | Val AUC 0.9260 | Val AUPR 0.6381
# 3Layer
# 3Layer
# Epoch 036 | Loss 0.3877 | Val AUC 0.9267 | Val AUPR 0.6427
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 037 | Loss 0.3869 | Val AUC 0.9277 | Val AUPR 0.6524
#    → Saved best model
# 3Layer
# 3Layer
# Epoch 038 | Loss 0.3862 | Val AUC 0.9274 | Val AUPR 0.6521
# 3Layer
# 3Layer
# Epoch 039 | Loss 0.3860 | Val AUC 0.9271 | Val AUPR 0.6517
# 3Layer
# 3Layer
# Epoch 040 | Loss 0.3846 | Val AUC 0.9268 | Val AUPR 0.6514
# 3Layer
# 3Layer
# Epoch 041 | Loss 0.3840 | Val AUC 0.9265 | Val AUPR 0.6470
# 3Layer
# 3Layer
# Epoch 042 | Loss 0.3833 | Val AUC 0.9263 | Val AUPR 0.6485
# 3Layer
# 3Layer
# Epoch 043 | Loss 0.3826 | Val AUC 0.9259 | Val AUPR 0.6380
# 3Layer
# 3Layer
# Epoch 044 | Loss 0.3824 | Val AUC 0.9259 | Val AUPR 0.6461
# 3Layer
# 3Layer
# Epoch 045 | Loss 0.3816 | Val AUC 0.9251 | Val AUPR 0.6463
# 3Layer
# 3Layer
# Epoch 046 | Loss 0.3794 | Val AUC 0.9245 | Val AUPR 0.6432
# 3Layer
# 3Layer
# Epoch 047 | Loss 0.3794 | Val AUC 0.9238 | Val AUPR 0.6389
# 3Layer
# 3Layer
# Epoch 048 | Loss 0.3778 | Val AUC 0.9236 | Val AUPR 0.6379
# 3Layer
# 3Layer
# Epoch 049 | Loss 0.3769 | Val AUC 0.9232 | Val AUPR 0.6350
# 3Layer
# 3Layer
# Epoch 050 | Loss 0.3774 | Val AUC 0.9226 | Val AUPR 0.6323
# 3Layer
# SEED 46 | Test AUC 0.9170 | Test AUPR 0.5760

# %%
results_df = pd.DataFrame(
    results,
    columns=["seed", "best_val_loss", "auc", "aupr"]
)

print("\n===== FINAL RESULTS =====")
print(results_df)
print("\nMean ± Std")
print(
    results_df[["best_val_loss", "auc", "aupr"]]
    .agg(["mean", "std"])
)
# Out:
# ===== FINAL RESULTS =====
#    seed  best_val_loss       auc      aupr
# 0    42       0.385279  0.921917  0.570025
# 1    43       0.396583  0.924483  0.616280
# 2    44       0.401772  0.929152  0.641099
# 3    45       0.385056  0.933215  0.596122
# 4    46       0.386855  0.916981  0.575985
#
# Mean ± Std
#       best_val_loss       auc      aupr
# mean       0.391109  0.925150  0.599902
# std        0.007622  0.006298  0.029344
